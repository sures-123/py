# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Read Excel Data**

# %%
df=pd.read_excel("/content/f1.xlsx")
df
# Out:
#                                             Unnamed: 0  Unnamed: 1 Unnamed: 2  \
# 0                   Detail Transaction Totals List for         NaN        NaN
# 1                               6/30/2023 to 6/30/2023         NaN        NaN
# 2                                                 Code         NaN       Room
# 3                                                  NaN         NaN        NaN
# 4    150 - STATE TAX - GL Account: 299.20812.0000.2...         NaN        NaN
# ..                                                 ...         ...        ...
# 906                                                151         NaN        192
# 907                                                NaN         NaN        NaN
# 908                                                NaN         NaN        NaN
# 909                                                NaN         NaN        NaN
# 910  RRI812 - Red Roof Inn & Suites Newark - Univer...         NaN        NaN
#
# ...

# %%
df.shape
# Out:
# (911, 30)

# %% [markdown]
# **Drop Empty Rows & Cols**

# %%
df.dropna(axis=1, how='all', inplace=True)
df.dropna(axis=0, how='all', inplace=True)
df
# Out:
#                                             Unnamed: 0 Unnamed: 2  Unnamed: 4  \
# 0                   Detail Transaction Totals List for        NaN         NaN
# 1                               6/30/2023 to 6/30/2023        NaN         NaN
# 2                                                 Code       Room     Account
# 4    150 - STATE TAX - GL Account: 299.20812.0000.2...        NaN         NaN
# 5                                            6/30/2023        NaN         NaN
# ..                                                 ...        ...         ...
# 905                                                151        120  812-139931
# 906                                                151        192  812-550313
# 907                                                NaN        NaN         NaN
# 908                                                NaN        NaN         NaN
# 910  RRI812 - Red Roof Inn & Suites Newark - Univer...        NaN         NaN
#
# ...

# %%
df.shape
# Out:
# (852, 14)

# %% [markdown]
# **Assign Lengths**

# %%
df.columns=np.arange(1,len(df.columns)+1)

# %% [markdown]
# **Drop Top Two Rows**

# %%
df.drop(df.head(2).index,inplace=True)
df
# Out:
#                                                     1     2           3    4   \
# 2                                                 Code  Room     Account  NaN
# 4    150 - STATE TAX - GL Account: 299.20812.0000.2...   NaN         NaN  NaN
# 5                                            6/30/2023   NaN         NaN  NaN
# 6                                                  150   182  812-072143  NaN
# 7                                                  150   159  812-006829  NaN
# ..                                                 ...   ...         ...  ...
# 905                                                151   120  812-139931  NaN
# 906                                                151   192  812-550313  NaN
# 907                                                NaN   NaN         NaN  NaN
# 908                                                NaN   NaN         NaN  NaN
# 910  RRI812 - Red Roof Inn & Suites Newark - Univer...   NaN         NaN  NaN
#
# ...

# %% [markdown]
# **Drop Last One Row By Using Index**

# %%
df = df.drop(df.index[-1])
df
# Out:
#                                                     1     2           3    4   \
# 2                                                 Code  Room     Account  NaN
# 4    150 - STATE TAX - GL Account: 299.20812.0000.2...   NaN         NaN  NaN
# 5                                            6/30/2023   NaN         NaN  NaN
# 6                                                  150   182  812-072143  NaN
# 7                                                  150   159  812-006829  NaN
# ..                                                 ...   ...         ...  ...
# 904                                                151   243  812-546944  NaN
# 905                                                151   120  812-139931  NaN
# 906                                                151   192  812-550313  NaN
# 907                                                NaN   NaN         NaN  NaN
# 908                                                NaN   NaN         NaN  NaN
#
# ...

# %% [markdown]
# **Drop First Row By Using Index**

# %%
df = df.drop(df.index[1])
df
# Out:
#             1     2           3    4                       5    6   \
# 2         Code  Room     Account  NaN                    Name  NaN
# 5    6/30/2023   NaN         NaN  NaN                     NaN  NaN
# 6          150   182  812-072143  NaN            ADAMS, DEVIN  NaN
# 7          150   159  812-006829  NaN         ANDERSON, SHAWN  NaN
# 8          150   123  812-133725  NaN         ANDING, BAHEERA  NaN
# ..         ...   ...         ...  ...                     ...  ...
# 904        151   243  812-546944  NaN       WILLIAMS, BRIDGET  NaN
# 905        151   120  812-139931  NaN    WINDSOR, MELINDA RAE  NaN
# 906        151   192  812-550313  NaN  WRIGHT, AMIE ELIZABETH  NaN
# 907        NaN   NaN         NaN  NaN                     NaN  NaN
# 908        NaN   NaN         NaN  NaN                     NaN  NaN
#
#              7       8                    9              10    11   12   13  \
# 2      Comments    User                  NaN            NaN  Time  NaN  NaN
# ...

# %% [markdown]
# **Again Drop First Row**

# %%
df = df.drop(df.index[1])
df
# Out:
#        1     2           3    4                        5    6           7   \
# 2    Code  Room     Account  NaN                     Name  NaN    Comments
# 6     150   182  812-072143  NaN             ADAMS, DEVIN  NaN   STATE TAX
# 7     150   159  812-006829  NaN          ANDERSON, SHAWN  NaN   STATE TAX
# 8     150   123  812-133725  NaN          ANDING, BAHEERA  NaN   STATE TAX
# 9     150   165  812-409733  NaN  ANDRADE, HEIDYKASSANDRA  NaN   STATE TAX
# ..    ...   ...         ...  ...                      ...  ...         ...
# 904   151   243  812-546944  NaN        WILLIAMS, BRIDGET  NaN  COUNTY TAX
# 905   151   120  812-139931  NaN     WINDSOR, MELINDA RAE  NaN  COUNTY TAX
# 906   151   192  812-550313  NaN   WRIGHT, AMIE ELIZABETH  NaN  COUNTY TAX
# 907   NaN   NaN         NaN  NaN                      NaN  NaN         NaN
# 908   NaN   NaN         NaN  NaN                      NaN  NaN         NaN
#
# ...

# %% [markdown]
# **Drop Row at Index [-2]**

# %%
df = df.drop(df.index[-2])
df
# Out:
#        1     2           3    4                             5    6   \
# 2    Code  Room     Account  NaN                          Name  NaN
# 6     150   182  812-072143  NaN                  ADAMS, DEVIN  NaN
# 7     150   159  812-006829  NaN               ANDERSON, SHAWN  NaN
# 8     150   123  812-133725  NaN               ANDING, BAHEERA  NaN
# 9     150   165  812-409733  NaN       ANDRADE, HEIDYKASSANDRA  NaN
# ..    ...   ...         ...  ...                           ...  ...
# 903   151   128  812-746676  NaN  WHITEHOUSE,CHRISTOPHER BRYAN  NaN
# 904   151   243  812-546944  NaN             WILLIAMS, BRIDGET  NaN
# 905   151   120  812-139931  NaN          WINDSOR, MELINDA RAE  NaN
# 906   151   192  812-550313  NaN        WRIGHT, AMIE ELIZABETH  NaN
# 908   NaN   NaN         NaN  NaN                           NaN  NaN
#
#              7       8    9              10    11   12   13       14
# 2      Comments    User  NaN            NaN  Time  NaN  NaN   Amount
# ...

# %%
df = df.drop(df.index[-1])
df
# Out:
#        1     2           3    4                             5    6   \
# 2    Code  Room     Account  NaN                          Name  NaN
# 6     150   182  812-072143  NaN                  ADAMS, DEVIN  NaN
# 7     150   159  812-006829  NaN               ANDERSON, SHAWN  NaN
# 8     150   123  812-133725  NaN               ANDING, BAHEERA  NaN
# 9     150   165  812-409733  NaN       ANDRADE, HEIDYKASSANDRA  NaN
# ..    ...   ...         ...  ...                           ...  ...
# 902   NaN   NaN         NaN  NaN                       ROSETTA  NaN
# 903   151   128  812-746676  NaN  WHITEHOUSE,CHRISTOPHER BRYAN  NaN
# 904   151   243  812-546944  NaN             WILLIAMS, BRIDGET  NaN
# 905   151   120  812-139931  NaN          WINDSOR, MELINDA RAE  NaN
# 906   151   192  812-550313  NaN        WRIGHT, AMIE ELIZABETH  NaN
#
#              7       8    9    10    11   12   13      14
# 2      Comments    User  NaN  NaN  Time  NaN  NaN  Amount
# ...

# %%
df = df.replace('[()]', '', regex=True)
df
# Out:
#        1     2           3    4                             5    6   \
# 2    Code  Room     Account  NaN                          Name  NaN
# 6     150   182  812-072143  NaN                  ADAMS, DEVIN  NaN
# 7     150   159  812-006829  NaN               ANDERSON, SHAWN  NaN
# 8     150   123  812-133725  NaN               ANDING, BAHEERA  NaN
# 9     150   165  812-409733  NaN       ANDRADE, HEIDYKASSANDRA  NaN
# ..    ...   ...         ...  ...                           ...  ...
# 902   NaN   NaN         NaN  NaN                       ROSETTA  NaN
# 903   151   128  812-746676  NaN  WHITEHOUSE,CHRISTOPHER BRYAN  NaN
# 904   151   243  812-546944  NaN             WILLIAMS, BRIDGET  NaN
# 905   151   120  812-139931  NaN          WINDSOR, MELINDA RAE  NaN
# 906   151   192  812-550313  NaN        WRIGHT, AMIE ELIZABETH  NaN
#
#              7       8    9    10    11   12   13      14
# 2      Comments    User  NaN  NaN  Time  NaN  NaN  Amount
# ...

# %% [markdown]
# **Delete Rows At Specific Indices**

# %%
row_indices_to_delete = [37, 38, 39,40]
df = df.drop(df.index[row_indices_to_delete])
df
# Out:
#        1     2           3    4                             5    6   \
# 2    Code  Room     Account  NaN                          Name  NaN
# 6     150   182  812-072143  NaN                  ADAMS, DEVIN  NaN
# 7     150   159  812-006829  NaN               ANDERSON, SHAWN  NaN
# 8     150   123  812-133725  NaN               ANDING, BAHEERA  NaN
# 9     150   165  812-409733  NaN       ANDRADE, HEIDYKASSANDRA  NaN
# ..    ...   ...         ...  ...                           ...  ...
# 902   NaN   NaN         NaN  NaN                       ROSETTA  NaN
# 903   151   128  812-746676  NaN  WHITEHOUSE,CHRISTOPHER BRYAN  NaN
# 904   151   243  812-546944  NaN             WILLIAMS, BRIDGET  NaN
# 905   151   120  812-139931  NaN          WINDSOR, MELINDA RAE  NaN
# 906   151   192  812-550313  NaN        WRIGHT, AMIE ELIZABETH  NaN
#
#              7       8    9    10    11   12   13      14
# 2      Comments    User  NaN  NaN  Time  NaN  NaN  Amount
# ...

# %%
row_indices_to_delete = [38, 39,77,78,80,82,83,115,116,117,118,120,121,122,123,125,126,164,165,166,167,169,170,215,216,217,218,220,221,257,258,259,260,262,263, 272,273,274,275,277,278,299,300,301,302,304,305,]
df = df.drop(df.index[row_indices_to_delete])
df
# Out:
#        1     2           3    4                             5    6   \
# 2    Code  Room     Account  NaN                          Name  NaN
# 6     150   182  812-072143  NaN                  ADAMS, DEVIN  NaN
# 7     150   159  812-006829  NaN               ANDERSON, SHAWN  NaN
# 8     150   123  812-133725  NaN               ANDING, BAHEERA  NaN
# 9     150   165  812-409733  NaN       ANDRADE, HEIDYKASSANDRA  NaN
# ..    ...   ...         ...  ...                           ...  ...
# 902   NaN   NaN         NaN  NaN                       ROSETTA  NaN
# 903   151   128  812-746676  NaN  WHITEHOUSE,CHRISTOPHER BRYAN  NaN
# 904   151   243  812-546944  NaN             WILLIAMS, BRIDGET  NaN
# 905   151   120  812-139931  NaN          WINDSOR, MELINDA RAE  NaN
# 906   151   192  812-550313  NaN        WRIGHT, AMIE ELIZABETH  NaN
#
#              7       8    9    10    11   12   13      14
# 2      Comments    User  NaN  NaN  Time  NaN  NaN  Amount
# ...

# %% [markdown]
# **Convert Excel To CSV File**

# %%
df.to_csv("file.csv")
